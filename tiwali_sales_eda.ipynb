# %% [markdown]
# <a href="https://colab.research.google.com/github/ftadithyan/PYTHON_DIWALI_SALES_ANALYSIS_/blob/main/tiwali_sales_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TIWALI _SALES_ANALYSIS

# %%
# Download the dataset file
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/MpykN-nosN1Sn19AVgzEOg/Diwali-Sales-Data.csv

# Load the dataset into a pandas DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Diwali-Sales-Data.csv', encoding='ISO-8859-1')

# Display the first few rows
df
# Out:
# --2025-08-29 06:36:25--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/MpykN-nosN1Sn19AVgzEOg/Diwali-Sales-Data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1033233 (1009K) [text/csv]
# Saving to: ‘Diwali-Sales-Data.csv.6’
#
# Diwali-Sales-Data.c 100%[===================>]   1009K  2.48MB/s    in 0.4s
#
# 2025-08-29 06:36:26 (2.48 MB/s) - ‘Diwali-Sales-Data.csv.6’ saved [1033233/1033233]
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount  Status  unnamed1
# 0      23952.0     NaN       NaN
# 1      23934.0     NaN       NaN
# 2      23924.0     NaN       NaN
# 3      23912.0     NaN       NaN
# 4      23877.0     NaN       NaN
# ...        ...     ...       ...
# 11246    370.0     NaN       NaN
# 11247    367.0     NaN       NaN
# 11248    213.0     NaN       NaN
# 11249    206.0     NaN       NaN
# 11250    188.0     NaN       NaN
#
# [11251 rows x 15 columns]

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# 2  23924.0     NaN       NaN
# 3  23912.0     NaN       NaN
# 4  23877.0     NaN       NaN

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# Status              float64
# unnamed1            float64
# dtype: object

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
df.describe(include="object")
# Out:
#        Cust_name Product_ID Gender Age Group          State     Zone  \
# count      11251      11251  11251     11251          11251    11251
# unique      1250       2351      2         7             16        5
# top     Vishakha  P00265242      F     26-35  Uttar Pradesh  Central
# freq          42         53   7842      4543           1946     4296
#
#        Occupation    Product_Category
# count       11251               11251
# unique         15                  18
# top     IT Sector  Clothing & Apparel
# freq         1588                2655

# %% [markdown]
#  we are calculating the total number of unique customers in our dataset by checking for unique entries in the User_ID column.

# %%
df['User_ID'].nunique()
# Out:
# 3755

# %% [markdown]
# Now, we are identifying the unique states represented in the dataset by checking distinct values in the State column.

# %%
df['State'].unique()
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Madhya Pradesh',
#        'Jharkhand', 'Kerala', 'Haryana', 'Bihar', 'Rajasthan',
#        'Uttarakhand', 'Telangana', 'Punjab'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 16

# %% [markdown]
# Now, we’re calculating the total number of missing values in each column to understand data completeness.

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.drop(['Status','unnamed1'],inplace=True,axis=1)
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## ANALYSIS

# %% [markdown]
# We are calculating the count of entries for each state in the dataset to understand the distribution of records across different geographical locations. This helps identify which states have a higher volume of customer engagement or activity. We will visualize this information using a bar chart.

# %%
state_count=df['State'].value_counts()
state_count
# Out:
# State
# Uttar Pradesh       1944
# Maharashtra         1525
# Karnataka           1304
# Delhi               1104
# Madhya Pradesh       921
# Andhra Pradesh       811
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              427
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: count, dtype: int64

# %%
state_count.plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ## Insights from state distribution
# Uttar Pradesh leads with the highest entries (1944), followed by Maharashtra (1525) and Karnataka (1304), indicating strong market presence.
# Moderate counts in Delhi (1104) and Madhya Pradesh (921) suggest opportunities for growth.
# States like Telangana (125) and Punjab (200) have lower engagement, indicating potential areas for targeted marketing efforts.
# This distribution can guide resource allocation and marketing strategies to enhance customer engagement across regions.

# %% [markdown]
# # Total sales per state

# %%
sales_state=df.groupby('State')['Amount'].sum().reset_index()
sales_state.columns=['state','total_sales']
sales_state
# Out:
#                state  total_sales
# 0     Andhra Pradesh   8037146.99
# 1              Bihar   4022757.00
# 2              Delhi  11603819.45
# 3            Gujarat   3946082.00
# 4            Haryana   4220175.00
# 5   Himachal Pradesh   4963368.00
# 6          Jharkhand   3026456.00
# 7          Karnataka  13523540.00
# 8             Kerala   3894491.99
# 9     Madhya Pradesh   8101142.00
# 10       Maharashtra  14427543.00
# 11            Punjab   1525800.00
# 12         Rajasthan   1909409.00
# 13         Telangana   1151490.00
# 14     Uttar Pradesh  19374968.00
# 15       Uttarakhand   2520944.00

# %%
sales_state = sales_state.sort_values(by='total_sales', ascending=False)

print(sales_state)
# Out:
#                state  total_sales
# 14     Uttar Pradesh  19374968.00
# 10       Maharashtra  14427543.00
# 7          Karnataka  13523540.00
# 2              Delhi  11603819.45
# 9     Madhya Pradesh   8101142.00
# 0     Andhra Pradesh   8037146.99
# 5   Himachal Pradesh   4963368.00
# 4            Haryana   4220175.00
# 1              Bihar   4022757.00
# 3            Gujarat   3946082.00
# 8             Kerala   3894491.99
# 6          Jharkhand   3026456.00
# 15       Uttarakhand   2520944.00
# 12         Rajasthan   1909409.00
# 11            Punjab   1525800.00
# 13         Telangana   1151490.00

# %%
plt.figure(figsize=(10, 6))
plt.bar(sales_state['state'], sales_state['total_sales'], color='skyblue')
plt.title('Total Sales per State')
plt.xlabel('State')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Highest Sales: Uttar Pradesh has the highest total sales amount at approximately ₹19,374,968, indicating a strong market presence or customer engagement in that region.
# Second Highest: Maharashtra follows closely with total sales of ₹14,427,543, also showcasing significant activity.
# Other Notable States: Karnataka and Delhi also report high sales figures of ₹13,523,540 and ₹11,603,819.45, respectively, highlighting these states as key contributors to overall sales.
# Lower Sales States: States like Punjab and Telangana show lower total sales amounts, with figures of ₹1,525,800 and ₹1,151,490, suggesting potential areas for growth or increased marketing efforts.

# %% [markdown]
# ## Average order value per state
#
# We are calculating the average order value for each state by dividing the total sales amount by the total number of orders. This metric helps to assess customer spending behavior and can indicate how much, on average, customers are willing to spend per order in different regions. Understanding average order value across states can inform pricing strategies, promotional efforts, and resource allocation.

# %%
average_order_value = df.groupby('State').agg({'Amount': 'sum', 'Orders': 'sum'}).reset_index()
average_order_value['Average_Order_Value'] = average_order_value['Amount'] / average_order_value['Orders']
average_order_value = average_order_value[['State', 'Average_Order_Value']]


plt.figure(figsize=(10, 6))
plt.bar(average_order_value['State'], average_order_value['Average_Order_Value'], color='lightgreen')
plt.title('Average Order Value per State')
plt.xlabel('State')
plt.ylabel('Average Order Value')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
average_order_value.sort_values(by='Average_Order_Value',ascending=False)
# Out:
#                State  Average_Order_Value
# 2              Delhi          4234.970602
# 7          Karnataka          4173.932099
# 14     Uttar Pradesh          4030.573747
# 0     Andhra Pradesh          3918.647972
# 4            Haryana          3805.387737
# 1              Bihar          3787.906780
# 10       Maharashtra          3786.756693
# 3            Gujarat          3701.765478
# 13         Telangana          3690.673077
# 9     Madhya Pradesh          3597.309947
# 12         Rajasthan          3440.376577
# 8             Kerala          3425.234820
# 6          Jharkhand          3175.714586
# 5   Himachal Pradesh          3165.413265
# 11            Punjab          3082.424242
# 15       Uttarakhand          3059.398058

# %% [markdown]
# HIGHEST-DELHI has the highest average order value at around  - 4235.
#
# LOWEST- Uttarakhand has the lowest average order value at around -3,059.

# %% [markdown]
# ## Orders by gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
orders_gender=df.groupby('Gender')['Orders'].sum().reset_index()
orders_gender
# Out:
#   Gender  Orders
# 0      F   19548
# 1      M    8433

# %%
plt.pie(orders_gender['Orders'], labels=orders_gender['Gender'], autopct='%1.1f%%',colors=['skyblue','yellow'])
plt.title('genders orders distribution')
plt.legend(title="Gender", loc="best")
plt.show()

# %% [markdown]
# The data reveals that female customers  made significantly more orders  than male customers

# %% [markdown]
# ## Orders by age group

# %%
orders_by_age = df.groupby('Age Group')['Orders'].sum().reset_index()

# Bar chart for orders by age group
plt.figure(figsize=(10, 6))
plt.bar(orders_by_age['Age Group'], orders_by_age['Orders'], color='skyblue')
plt.title('Orders by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Orders')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# The 26-35 age group is the largest contributor to orders, indicating strong purchasing power and engagement.
# Young adults (18-25) also show notable activity, suggesting opportunities for trend-driven marketing.

# %% [markdown]
# #TOP SELLING PRODUCTS

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sales_by_category = df.groupby('Product_Category').agg({'Orders': 'sum', 'Amount': 'sum'}).reset_index()
sales_by_category
# Out:
#          Product_Category  Orders       Amount
# 0                    Auto     239   1958609.99
# 1                  Beauty    1086   1959484.00
# 2                   Books     245   1061478.00
# 3      Clothing & Apparel    6634  16495019.00
# 4                   Decor     235    730360.00
# 5   Electronics & Gadgets    5226  15643846.00
# 6                    Food    6110  33933883.50
# 7        Footwear & Shoes    2646  15575209.45
# 8               Furniture     889   5440051.99
# 9            Games & Toys     940   4331694.00
# 10     Hand & Power Tools      80    405618.00
# 11        Household items    1331   1569337.00
# 12                 Office     261     81936.00
# 13               Pet Care     536    482277.00
# 14        Sports Products     870   3635933.00
# 15             Stationery     281   1676051.50
# 16             Tupperware     166   1155642.00
# 17             Veterinary     206    112702.00

# %%
# Bar chart for sales by product category
plt.figure(figsize=(10, 6))
plt.bar(sales_by_category['Product_Category'], sales_by_category['Orders'], color='cyan')
plt.title('Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Number of Orders')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ood leads in both orders (6,110) and revenue ($33.9M), showing strong consumer demand.
# Electronics & Gadgets (5,226 orders, $15.6M) and Clothing & Apparel (6,634 orders, $16.5M) also perform well, indicating popular consumer interests.
# Footwear & Shoes generates substantial sales ($15.6M) with 2,646 orders.
# Beauty (1,086 orders, $1.96M) and Sports Products (870 orders, $3.6M) show potential for growth.
# Categories like Auto (239 orders, $1.96M) and Hand & Power Tools (80 orders, $405K) are underperforming and may need targeted marketing.

# %% [markdown]
# TOP SELLING BASED ON PRODUCT_ID

# %%
top_products = df.groupby('Product_ID')['Orders'].sum().reset_index()
top_products.columns = ['Product_ID', 'Total_Orders']
top_products = top_products.sort_values(by='Total_Orders', ascending=False)

# %%
top_20_products = top_products.head(20)
top_20_products
# Out:
#      Product_ID  Total_Orders
# 1679  P00265242           127
# 644   P00110942           116
# 1504  P00237542            91
# 1146  P00184942            82
# 171   P00025442            79
# 679   P00114942            79
# 888   P00145042            76
# 708   P00117942            76
# 298   P00044442            75
# 643   P00110842            74
# 642   P00110742            73
# 388   P00058042            72
# 195   P00028842            71
# 1357  P00216342            71
# 613   P00106042            70
# 396   P00059442            70
# 492   P00080342            69
# 658   P00112542            68
# 1593  P00251242            68
# 912   P00148642            67

# %%
plt.figure(figsize=(12, 6))
plt.bar(top_20_products['Product_ID'], top_20_products['Total_Orders'], color='purple')
plt.title('Top 20 Selling Products')
plt.xlabel('Product ID')
plt.ylabel('Total Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# P00265242 (127),P00110942 (	116 ),P00237542	(91) P00184942	(82) THESE ARE THE HIGHEST ORDERS PRODUCT ID'S AND ORDERS

# %% [markdown]
# ## Total orders by occupation

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
order_occupation=df.groupby('Occupation')['Orders'].sum().reset_index()
order_occupation.columns=['occupation','orders']
order_occupation.sort_values(by='orders',ascending=False)
# Out:
#          occupation  orders
# 10        IT Sector    3997
# 8        Healthcare    3455
# 2          Aviation    3215
# 3           Banking    2817
# 7              Govt    2155
# 9       Hospitality    1739
# 12            Media    1596
# 1        Automobile    1371
# 11           Lawyer    1344
# 4          Chemical    1309
# 13           Retail    1270
# 6   Food Processing    1073
# 5      Construction    1025
# 14          Textile     893
# 0       Agriculture     722

# %%
plt.figure(figsize=(15,10))
plt.pie(order_occupation['orders'], labels=order_occupation['occupation'], autopct='%1.1f%%')
plt.title("TOTAL ORDERS BY OCCUPATION")

plt.show()

# %% [markdown]
# IT Sector leads with the highest number of orders (3,997), indicating a strong consumer engagement in technology-related products or services.
# Healthcare and Aviation follow closely, with orders of 3,455 and 3,215, respectively, highlighting significant demand in these critical sectors.
# Other notable occupations include Banking (2,817), Government (2,155), and Hospitality (1,739), each demonstrating considerable order volumes.
# Occupations such as Retail (1,270) and Construction (1,025) also contribute to the overall order count, suggesting diverse consumer interests across various fields.

# %% [markdown]
# ## Order distribution
# ### In this analysis, we visualize the distribution of the number of orders placed using a histogram combined with a kernel density estimate (KDE). This helps us understand customer purchasing behavior, particularly the frequency of different order sizes.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Orders'],kde=True, color='red')
plt.title('Distribution of Orders')
plt.xlabel('Number of Orders')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Amount distribution

# %%
plt.figure(figsize=(10,7))
sns.histplot(df['Amount'], bins=30, kde=True, color='purple')
plt.title('Distribution of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Total count of each gender based on marital status
# > Add blockquote

# %%
ms = df.groupby(['Marital_Status', 'Gender']).size().reset_index(name='counts').sort_values('counts', ascending=False)


ms['Marital_Status'] = ms['Marital_Status'].replace({'0': 'Not Married', '1': 'Married'})
ms['Gender'] = ms['Gender'].replace({'F': 'Female', 'M': 'Male'})


plt.figure(figsize=(10, 6))
sns.barplot(data=ms, x='Marital_Status', y='counts', hue='Gender')


plt.title("Total Count of Each Gender Based on Marital Status")
plt.xlabel('Marital Status')
plt.ylabel('Number of Orders')
plt.legend(title='Gender')
plt.tight_layout()

# Show the figure
plt.show()

# %%
ms
# Out:
#    Marital_Status  Gender  counts
# 0               0  Female    4573
# 2               1  Female    3259
# 1               0    Male    1945
# 3               1    Male    1462

# %% [markdown]
# The data indicates that Females are more active in placing orders compared to Males, regardless of marital status. Specifically, 4,573 orders were recorded from Not Married Females, while 1,945 orders were placed by Not Married Males. Among Married individuals, 3,259 orders were attributed to Married Females, compared to 1,462 orders from Married Males. This suggests a strong engagement from female customers, particularly those who are not married, presenting an opportunity for targeted marketing strategies.

# %% [markdown]
# ## Total orders by zone

# %%
zone_orders = df.groupby('Zone')['Orders'].sum().reset_index()
zone_orders.columns = ['Zone', 'Total_Orders']
zone_orders
# Out:
#        Zone  Total_Orders
# 0   Central         10623
# 1   Eastern          2015
# 2  Northern          3727
# 3  Southern          6740
# 4   Western          4876

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=zone_orders, x='Zone', y='Total_Orders', palette='viridis')

plt.title("Total Orders by Zone")
plt.xlabel('Zone')
plt.ylabel('Total Orders')
plt.tight_layout()

# Show the figure
plt.show()
# Out:
# /tmp/ipython-input-2885597552.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=zone_orders, x='Zone', y='Total_Orders', palette='viridis')

# %% [markdown]
# ### Central Zone Dominance: The Central zone leads with 10,623 orders, indicating strong engagement and spending during Diwali.
#
# ### Low Engagement in Eastern Zone: The Eastern zone's 2,015 orders suggest potential cultural differences or market challenges.

# %% [markdown]
# #MOST VALUABLE CUSTOMER

# %%
customer=df['Cust_name'].value_counts().reset_index()
customer.columns=['customer','number_of_times_purchase']
customer.head(10)
# Out:
#     customer  number_of_times_purchase
# 0   Vishakha                        42
# 1   Shreyshi                        32
# 2     Sudevi                        30
# 3     Akshat                        29
# 4  Alejandro                        28
# 5     Aastha                        27
# 6      Stuti                        25
# 7      Hazel                        25
# 8   Halladay                        25
# 9    Vasudev                        24

# %% [markdown]
# ## TOP REVENUE PRODUCTS

# %%
product_sales=df.groupby('Product_Category')['Amount'].sum()
top = product_sales.sort_values(ascending=False)

# %%
top_5=top.head(5)
top_5
# Out:
# Product_Category
# Food                     33933883.50
# Clothing & Apparel       16495019.00
# Electronics & Gadgets    15643846.00
# Footwear & Shoes         15575209.45
# Furniture                 5440051.99
# Name: Amount, dtype: float64

# %%
ax = top_5.plot(kind='bar', color='orange')

ax.ticklabel_format(style='plain', axis='y')

plt.show()

# %% [markdown]
# #LOW SALES PRODUCTS

# %%
bottom = product_sales.sort_values(ascending=True)
bottom_5=bottom.head(5)
bottom_5
# Out:
# Product_Category
# Office                 81936.0
# Veterinary            112702.0
# Hand & Power Tools    405618.0
# Pet Care              482277.0
# Decor                 730360.0
# Name: Amount, dtype: float64

# %%
ax = bottom_5.plot(kind='bar', color='orange')

ax.ticklabel_format(style='plain', axis='y')

plt.show()

# %% [markdown]
# #                                                                             clusters

# %% [markdown]
# office ,veterinary ,products least sell compare to others.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans

# %%
pdf = pd.read_csv('Diwali-Sales-Data.csv', encoding='ISO-8859-1')
pdf
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount  Status  unnamed1
# 0      23952.0     NaN       NaN
# 1      23934.0     NaN       NaN
# 2      23924.0     NaN       NaN
# 3      23912.0     NaN       NaN
# 4      23877.0     NaN       NaN
# ...        ...     ...       ...
# 11246    370.0     NaN       NaN
# 11247    367.0     NaN       NaN
# 11248    213.0     NaN       NaN
# 11249    206.0     NaN       NaN
# 11250    188.0     NaN       NaN
#
# [11251 rows x 15 columns]

# %%
data = df[['Gender', 'Age', 'Marital_Status', 'State', 'Zone',
           'Occupation', 'Product_Category', 'Orders', 'Amount']]

# %%
for col in ['Gender', 'State', 'Zone', 'Occupation', 'Product_Category']:
    data.loc[:, col] = le.fit_transform(data[col])

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# %%
inertia = []
K = range(1, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)
plt.plot(K, inertia, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
df['Cluster'] = kmeans.fit_predict(data_scaled)

# %%
print(df.groupby('Cluster')[['Age', 'Marital_Status', 'Orders', 'Amount']].mean())
# Out:
#                Age  Marital_Status    Orders       Amount
# Cluster
# 0        35.528363        0.000000  3.520259  9404.149712
# 1        35.224693        1.000000  2.484786  9333.289933
# 2        34.953260        0.000000  1.484625  9720.712977
# 3        35.910776        0.447152  2.463624  9413.070350

# %% [markdown]
# Cluster 0 = Loyal frequent unmarried customers
#
# Cluster 1 = Married but moderate buyers
#
# Cluster 2 = Rare but premium buyers
#
# Cluster 3 = Mixed balanced segment
